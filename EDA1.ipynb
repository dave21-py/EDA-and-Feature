# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('zomato.csv', encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info() #object is string, int64 is integer, float64 is float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe() #gives statistical summary of numerical columns
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # In Data Analysis, we do
# 1. Missing values
# 2. Explore the numerical varibales
# 3. Explore the categorical variables
# 4. Findinf the realationsjip between features

# %%
df.isnull().sum() #check for null values in each column
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum() > 0] #list of features with null values, a list comprehension
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis') #visualize null values
# Out:
# <Axes: >

# %%
df_country = pd.read_excel('Country-Code.xlsx') #read country code data
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df, df_country, on='Country Code', how='left') #merge dataframes on 'Country Code'

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_counts = final_df.Country.value_counts().index #count of unique values in 'Country Code'
country_counts
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_values = final_df.Country.value_counts().values #count of unique values in 'Country Code'
country_values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4])

# %%
#Pie chart of top 3 countries by count
plt.pie(country_values[:3], labels=country_counts[:3], autopct='%1.2f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x120c4dbe0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.030157837943120734, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.016449729787156763, '0.87%')])

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating count'}) #.reset_index() converts the groupby object to a DataFrame
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
#Conclusions
# 1. Whenever the rating is from 4.5 to 5, the rating color is 'Dark Green' and the rating text is 'Excellent'.
# 2. Whenever the rating is from 4 to 4.5, the rating color is 'Green' and the rating text is 'Very Good'.
# 3. Whenever the rating is from 3.5 to 4, the rating color is 'Yellow' and the rating text is 'Good'.
# 4. Whenever the rating is from 2.5 to 3.5, the rating color is 'Orange' and the rating text is 'Average'.
# 5. Whenever the rating is less than 2.5, the rating color is 'Red' and the rating text is 'Poor'.

# %%
ratings.head(3)
# Out:
#    Aggregate rating Rating color Rating text  Rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,6)
sns.barplot(x='Aggregate rating', y='Rating count', data=ratings, hue='Rating color', palette=['Blue','Red','Orange','Yellow','Green','Cyan']) #bar plot of ratings
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating count'>

# %%
#Observations
# 1. There are no restaurants with an aggregate rating of 0.
# 2. The maximum number of restaurants have an aggregate rating of 4.0.

# %%
sns.countplot(x='Rating color', data=ratings, palette=['Blue','Red','Orange','Yellow','Green','Cyan']) #count plot of rating colors
# Out:
# /var/folders/3p/g7b0jvj960n96m4jk_07xl8c0000gn/T/ipykernel_61477/2908428708.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color', data=ratings, palette=['Blue','Red','Orange','Yellow','Green','Cyan']) #count plot of rating colors
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().reset_index() #group by aggregate rating and country
# Out:
#      Aggregate rating         Country     0
# 0                 0.0          Brazil     5
# 1                 0.0           India  2139
# 2                 0.0  United Kingdom     1
# 3                 0.0   United States     3
# 4                 1.8           India     1
# ..                ...             ...   ...
# 217               4.9       Sri Lanka     1
# 218               4.9          Turkey     3
# 219               4.9             UAE     4
# 220               4.9  United Kingdom     4
# 221               4.9   United States    14
#
# [222 rows x 3 columns]

# %%
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index() #find countries with no ratings
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
#Find out which currency is used by which country

# %%
final_df.groupby(['Currency', 'Country']).size().reset_index() #group by currency and country
# Out:
#                   Currency         Country     0
# 0         Botswana Pula(P)     Phillipines    22
# 1       Brazilian Real(R$)          Brazil    60
# 2                Dollar($)       Australia    24
# 3                Dollar($)          Canada     4
# 4                Dollar($)       Singapore    20
# 5                Dollar($)   United States   434
# 6       Emirati Diram(AED)             UAE    60
# 7       Indian Rupees(Rs.)           India  8652
# 8   Indonesian Rupiah(IDR)       Indonesia    21
# 9            NewZealand($)     New Zealand    40
# 10              Pounds(£)  United Kingdom    80
# 11         Qatari Rial(QR)           Qatar    20
# 12                 Rand(R)    South Africa    60
# 13   Sri Lankan Rupee(LKR)       Sri Lanka    20
# 14        Turkish Lira(TL)          Turkey    34

# %%
#Which countries have online delivery available?

# %%
final_df.groupby(['Has Online delivery', 'Country']).size().reset_index() #group by online delivery and country
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %%
#Find the top 10 cuisines in India

# %%
final_df[final_df['Country']=='India'].groupby('Cuisines').size().reset_index().head(10) #group by cuisines in India and get the top 10
# Out:
#                                             Cuisines  0
# 0                                            Afghani  4
# 1                          Afghani, Mughlai, Chinese  1
# 2                              Afghani, North Indian  1
# 3          Afghani, North Indian, Pakistani, Arabian  1
# 4                                           American  6
# 5                 American, Asian, European, Seafood  1
# 6  American, Asian, North Indian, Mexican, South ...  1
# 7                     American, British, Continental  1
# 8                             American, Burger, Cafe  1
# 9                        American, Burger, Fast Food  1
